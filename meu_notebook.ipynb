# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('ocorrencia.csv', sep=',', parse_dates=['ocorrencia_dia'], dayfirst=True)
#df = pd.DataFrame([{'A': 10, 'ocorrencia_dia': '03/07/1987'}])

# %%
schema = pa.DataFrameSchema(
    columns = {
        'ocorrencia_dia':pa.Column(pa.DateTime, nullable=True),
        'codigo_ocorrencia':pa.Column(pa.Int),
        'ocorrencia_cidade':pa.Column(pa.String)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# 1               SP                 SBGR     2012-01-06        13:44:00
# 2               RS                 ****     2012-01-06        13:00:00
# 3               SP                 ****     2012-01-06        17:00:00
# 4               RS                 ****     2012-01-06        16:30:00
# ...            ...                  ...            ...             ...
# 5162            GO                 ####     2021-12-30        20:30:00
# 5163            SP                *****     2021-12-31        09:30:00
# 5164            RS                 SSNH     2021-12-31        11:59:00
# 5165            PR                 SBBI     2021-12-31        15:12:00
# 5166            PE                 SBPL     2021-12-31        20:30:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               ***          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               NaN          FINALIZADA
# 3                               ***                 NaN
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 5162                            SIM               ATIVA
# 5163                            SIM               ATIVA
# 5164                            SIM          FINALIZADA
# 5165                            SIM          FINALIZADA
# 5166                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1              A-582/CENIPA/2014                            SIM
# 2              A-070/CENIPA/2013                            SIM
# 3                            NaN                            NÃO
# 4              A-071/CENIPA/2013                            SIM
# ...                          ...                            ...
# 5162                   A DEFINIR                            NÃO
# 5163                   A DEFINIR                            NÃO
# 5164                         ***                            NÃO
# 5165                         ***                            NÃO
# 5166                         ***                            NÃO
#
#      divulgacao_dia_publicacao      outras Unnamed: 16
# 0                          NaN  03/07/1987         NaN
# 1                   2016-09-01         NaN         NaN
# 2                   2013-11-27         NaN         NaN
# 3                          NaN         NaN         NaN
# 4                   2013-11-27         NaN         NaN
# ...                        ...         ...         ...
# 5162                       NaN         NaN         NaN
# 5163                       NaN         NaN         NaN
# 5164                       NaN         NaN         NaN
# 5165                       NaN         NaN         NaN
# 5166                       NaN         NaN         NaN
#
# [5167 rows x 17 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# outras                                    object
# Unnamed: 16                               object
# dtype: object
